# %% [markdown]
# # Step 1: Load and Inspect the Data

# %%
import pandas as pd

# Load the data
pre_covid_data = pd.read_csv('pre_covid_data(1).csv')
post_covid_data = pd.read_csv('covid_data(1).csv')

# Display the first few rows of each dataset
print("Pre-COVID Data:")
print(pre_covid_data.head())
print("\nPost-COVID Data:")
print(post_covid_data.head())
# Out:
# Pre-COVID Data:
#                         App Name        Category  Rating  Reviews        Size  \
# 0  Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260  25000000.0
# 1  Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260  25000000.0
# 2  Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260  25000000.0
# 3  Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260  25000000.0
# 4  Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260  25000000.0
#
#    Installs  Type  Price Content Rating                   Genres  ...  \
# 0    500000  Free    0.0       Everyone  Art & Design;Creativity  ...
# 1    500000  Free    0.0       Everyone  Art & Design;Creativity  ...
# 2    500000  Free    0.0       Everyone  Art & Design;Creativity  ...
# 3    500000  Free    0.0       Everyone  Art & Design;Creativity  ...
# 4    500000  Free    0.0       Everyone  Art & Design;Creativity  ...
#
#     Android Ver                                  Translated_Review Sentiment  \
# 0  4.0.3 and up  Good luck getting pictures free. Everyday supp...  Positive
# 1  4.0.3 and up  Good luck getting pictures free. Everyday supp...  Positive
# 2  4.0.3 and up  Good luck getting pictures free. Everyday supp...  Positive
# 3  4.0.3 and up  Good luck getting pictures free. Everyday supp...  Positive
# 4  4.0.3 and up  This terrible - there's way get back color cho...  Negative
#
#   Sentiment_Polarity Sentiment_Subjectivity  Review Date  \
# 0               0.15               0.720833   20-04-2020
# 1               0.15               0.720833   19-03-2020
# 2               0.15               0.720833   16-03-2020
# 3               0.15               0.720833   03-12-2019
# 4              -0.25               0.375000   20-04-2020
#
#                                              content sentiment polarity  \
# 0                                              Плохо   neutral  0.00000
# 1  DO NOT USE AUDIBLE! Scam warning. So I paid mo...  positive  0.07500
# 2  Well. I thought about trying it, and I was tol...  negative -0.27381
# 3  Edit: terrible customer service. They mistaken...  negative -0.33000
# 4                                              Плохо   neutral  0.00000
#
#   subjectivity
# 0     0.000000
# 1     0.275000
# 2     0.511905
# 3     0.578333
# 4     0.000000
#
# [5 rows x 22 columns]
#
# Post-COVID Data:
#              App Name        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Floor Plan Creator  ART_AND_DESIGN     4.1    36639   NaN   5000000  Free
# 1  Floor Plan Creator  ART_AND_DESIGN     4.1    36639   NaN   5000000  Free
# 2  Floor Plan Creator  ART_AND_DESIGN     4.1    36639   NaN   5000000  Free
# 3  Floor Plan Creator  ART_AND_DESIGN     4.1    36639   NaN   5000000  Free
# 4  Floor Plan Creator  ART_AND_DESIGN     4.1    36639   NaN   5000000  Free
#
#    Price Content Rating        Genres  ...   Android Ver  \
# 0    0.0       Everyone  Art & Design  ...  2.3.3 and up
# 1    0.0       Everyone  Art & Design  ...  2.3.3 and up
# 2    0.0       Everyone  Art & Design  ...  2.3.3 and up
# 3    0.0       Everyone  Art & Design  ...  2.3.3 and up
# 4    0.0       Everyone  Art & Design  ...  2.3.3 and up
#
#                                    Translated_Review Sentiment  \
# 0  I like features. It addictive! But, here's sug...  Positive
# 1  I like features. It addictive! But, here's sug...  Positive
# 2  I like features. It addictive! But, here's sug...  Positive
# 3  I like features. It addictive! But, here's sug...  Positive
# 4  I like features. It addictive! But, here's sug...  Positive
#
#   Sentiment_Polarity Sentiment_Subjectivity  Review Date  \
# 0            0.12619               0.546032   21-05-2020
# 1            0.12619               0.546032   21-04-2020
# 2            0.12619               0.546032   25-04-2020
# 3            0.12619               0.546032   21-05-2020
# 4            0.12619               0.546032   24-04-2020
#
#                                              content sentiment  polarity  \
# 0  Noticed the last week or so the app isn't coun...  negative -0.062500
# 1  I love this app it helps me keep up with my wa...  positive  0.500000
# 2  This app was great until the recent changes, i...  positive  0.400000
# 3  I use to be able to use this as a pulse oximet...  negative -0.033333
# 4  Some of the better parts of this app have disa...  negative -0.140000
#
#   subjectivity
# 0     0.345833
# 1     0.600000
# 2     0.500000
# 3     0.666667
# 4     0.705000
#
# [5 rows x 22 columns]

# %% [markdown]
# # Step 2: Analyze Sentiment Changes Pre- and Post-COVID-19

# %%
# Calculate sentiment distributions
pre_covid_sentiment = pre_covid_data['sentiment'].value_counts(normalize=True) * 100
post_covid_sentiment = post_covid_data['sentiment'].value_counts(normalize=True) * 100

print("Pre-COVID Sentiment Distribution:")
print(pre_covid_sentiment)
print("\nPost-COVID Sentiment Distribution:")
print(post_covid_sentiment)
# Out:
# Pre-COVID Sentiment Distribution:
# sentiment
# positive    65.080264
# negative    26.066100
# neutral      8.853636
# Name: proportion, dtype: float64
#
# Post-COVID Sentiment Distribution:
# sentiment
# positive    61.041635
# negative    24.378527
# neutral     14.579838
# Name: proportion, dtype: float64

# %% [markdown]
# # Step 3: Visualize the Sentiment Changes

# %%
#Bar Chart
import matplotlib.pyplot as plt

# Combine data for plotting
sentiment_df = pd.DataFrame({
    'Pre-COVID': pre_covid_sentiment,
    'Post-COVID': post_covid_sentiment
})

# Bar chart
sentiment_df.plot(kind='bar', figsize=(10, 6))
plt.title('Sentiment Distribution Pre- and Post-COVID-19')
plt.xlabel('Sentiment')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)
plt.legend(loc='upper right')
plt.show()

# %%
#Pie Chart

# Pie chart for pre-COVID sentiment
pre_covid_sentiment.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Pre-COVID Sentiment Distribution')
plt.ylabel('')
plt.show()

# Pie chart for post-COVID sentiment
post_covid_sentiment.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Post-COVID Sentiment Distribution')
plt.ylabel('')
plt.show()

# %%
# Line Char
# Line chart to compare sentiments
sentiment_df.plot(kind='line', marker='o', figsize=(10, 6))
plt.title('Sentiment Trends Pre- and Post-COVID-19')
plt.xlabel('Sentiment')
plt.ylabel('Percentage (%)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
